# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/raw/GOOGL.csv')
print(df.columns)
print(df.head())
# Out:
# Index(['Price', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
#         Price               Close               High                 Low  \
# 0      Ticker               GOOGL              GOOGL               GOOGL
# 1        Date                 NaN                NaN                 NaN
# 2  2015-01-02  26.319652557373047  26.63028955632621  26.236648546281916
# 3  2015-01-05  25.818159103393555  26.24211680222551  25.733170002740895
# 4  2015-01-06   25.18098258972168  25.90513806417547  25.126806918150155
#
#                  Open    Volume
# 0               GOOGL     GOOGL
# 1                 NaN       NaN
# 2  26.471241668562634  26480000
# 3  26.200367371172735  41182000
# 4  25.869850124114954  54456000

# %%
df = pd.read_csv('../data/raw/GOOGL.csv', skiprows=2, parse_dates=[0], index_col=0)

# %%
df.index.name = 'Date'

# %%
print(df.head())
print(df.info())
# Out:
#             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# Date
# 2015-01-02   26.319653   26.630290   26.236649   26.471242    26480000
# 2015-01-05   25.818159   26.242117   25.733170   26.200367    41182000
# 2015-01-06   25.180983   25.905138   25.126807   25.869850    54456000
# 2015-01-07   25.106926   25.422036   25.032374   25.395198    46918000
# 2015-01-08   25.194401   25.223724   24.603443   24.926010    73054000
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2015-01-02 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 1  2516 non-null   float64
#  1   Unnamed: 2  2516 non-null   float64
#  2   Unnamed: 3  2516 non-null   float64
#  3   Unnamed: 4  2516 non-null   float64
#  4   Unnamed: 5  2516 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB
# None

# %%
df.columns = ['Open', 'High', 'Low', 'Close', 'Volume']

# %%
print(df.head())
print(df.info())
# Out:
#                  Open       High        Low      Close    Volume
# Date
# 2015-01-02  26.319653  26.630290  26.236649  26.471242  26480000
# 2015-01-05  25.818159  26.242117  25.733170  26.200367  41182000
# 2015-01-06  25.180983  25.905138  25.126807  25.869850  54456000
# 2015-01-07  25.106926  25.422036  25.032374  25.395198  46918000
# 2015-01-08  25.194401  25.223724  24.603443  24.926010  73054000
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2516 entries, 2015-01-02 to 2024-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    2516 non-null   float64
#  1   High    2516 non-null   float64
#  2   Low     2516 non-null   float64
#  3   Close   2516 non-null   float64
#  4   Volume  2516 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 117.9 KB
# None

# %%
print(df.isnull().sum())
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
df['MA_7'] = df['Close'].rolling(window=7).mean()
df['MA_30'] = df['Close'].rolling(window=30).mean()

# %%
plt.figure(figsize=(14,7))

plt.plot(df['MA_7'], label='7-day MA')
plt.plot(df['MA_30'], label='30-day MA')
plt.title('GOOGLE Moving Averages')
plt.legend()
plt.show()

# %%
df['Return'] = df['Close'].pct_change()

# %%
plt.figure(figsize=(14,7))
plt.plot(df['Close'], label='Close Price')
plt.title('GOOGL Closing Price (2015–2025)')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(df['Close'].dropna())
print('ADF Statistic:', result[0])
print('p-value:', result[1])
# Out:
# ADF Statistic: 0.7358915424803308
# p-value: 0.9905275918850002

# %%
df['Close_diff'] = df['Close'] - df['Close'].shift(1)

# %%
diff_series = df['Close_diff'].dropna()

# %%
from statsmodels.tsa.stattools import adfuller

result_diff = adfuller(diff_series)

print('ADF:', result_diff[0])
print('p:', result_diff[1])

if result_diff[1] < 0.05:
    print("Stationary")
else:
    print("Not stationary")
# Out:
# ADF: -10.578278989296683
# p: 7.012665453609692e-19
# Stationary

# %%
plt.figure(figsize=(14,6))
plt.plot(diff_series)
plt.title('Differenced GOOGL Closing Prices')
plt.xlabel('Date')
plt.ylabel('First Difference of Close')
plt.grid(True)
plt.show()

# %%
split = int(0.8 * len(diff_series))
train = diff_series[:split]
test = diff_series[split:]

# %%
import numpy
import tensorflow
print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 2.3.2
# 2.19.0

# %%
pip uninstall numpy pmdarima tensorflow
pip install "numpy>=1.21.2,<2.0.0" pmdarima tensorflow"
# Out:
#   Cell In[30], line 2
#     pip install "numpy>=1.21.2,<2.0.0" pmdarima tensorflow"
#                                                           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
pip uninstall numpy pmdarima tensorflow
pip install "numpy>=1.21.2,<2.0.0" pmdarima tensorflow
# Out:
#   Cell In[31], line 1
#     pip uninstall numpy pmdarima tensorflow
#         ^
# SyntaxError: invalid syntax

# %%
pip uninstall -y numpy pmdarima tensorflow
pip install "numpy>=1.21.2,<2.0.0" pmdarima tensorflow
# Out:
#   Cell In[32], line 1
#     pip uninstall -y numpy pmdarima tensorflow
#         ^
# SyntaxError: invalid syntax

# %%
# !pip uninstall -y numpy pmdarima tensorflow
# !pip install "numpy>=1.21.2,<2.0.0" pmdarima tensorflow
# Out:
# Found existing installation: numpy 2.3.2
# Uninstalling numpy-2.3.2:
#   Successfully uninstalled numpy-2.3.2
# Found existing installation: pmdarima 2.0.4
# Uninstalling pmdarima-2.0.4:
#   Successfully uninstalled pmdarima-2.0.4
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# WARNING: Failed to remove contents in a temporary directory 'D:\stock_forecasting_project\venv\Lib\site-packages\~ensorflow'.
# You can safely remove it manually.
# Collecting numpy<2.0.0,>=1.21.2
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting pmdarima
#   Using cached pmdarima-2.0.4-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: joblib>=0.11 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (1.5.1)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (3.1.2)
# Requirement already satisfied: pandas>=0.19 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (2.3.1)
# Requirement already satisfied: scikit-learn>=0.22 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (1.7.1)
# Requirement already satisfied: scipy>=1.3.2 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (1.16.1)
# Requirement already satisfied: statsmodels>=0.13.2 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (0.14.5)
# Requirement already satisfied: urllib3 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (80.9.0)
# Requirement already satisfied: packaging>=17.1 in d:\stock_forecasting_project\venv\lib\site-packages (from pmdarima) (25.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: six>=1.12.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: h5py>=3.11.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\stock_forecasting_project\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\stock_forecasting_project\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\stock_forecasting_project\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\stock_forecasting_project\venv\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\stock_forecasting_project\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in d:\stock_forecasting_project\venv\lib\site-packages (from keras>=3.5.0->tensorflow) (14.1.0)
# Requirement already satisfied: namex in d:\stock_forecasting_project\venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in d:\stock_forecasting_project\venv\lib\site-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\stock_forecasting_project\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\stock_forecasting_project\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\stock_forecasting_project\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\stock_forecasting_project\venv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in d:\stock_forecasting_project\venv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\stock_forecasting_project\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\stock_forecasting_project\venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\stock_forecasting_project\venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in d:\stock_forecasting_project\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ----- ---------------------------------- 2.1/15.8 MB 11.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.7/15.8 MB 12.4 MB/s eta 0:00:01
#    ------------------- -------------------- 7.9/15.8 MB 13.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.3/15.8 MB 14.1 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 14.4 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 13.6 MB/s  0:00:01
# Using cached pmdarima-2.0.4-cp311-cp311-win_amd64.whl (614 kB)
# Downloading tensorflow-2.19.0-cp311-cp311-win_amd64.whl (375.9 MB)
#    ---------------------------------------- 0.0/375.9 MB ? eta -:--:--
#    ---------------------------------------- 3.9/375.9 MB 19.6 MB/s eta 0:00:19
#     --------------------------------------- 8.1/375.9 MB 19.4 MB/s eta 0:00:19
#    - -------------------------------------- 12.3/375.9 MB 19.3 MB/s eta 0:00:19
#    - -------------------------------------- 16.5/375.9 MB 19.6 MB/s eta 0:00:19
#    -- ------------------------------------- 21.0/375.9 MB 19.8 MB/s eta 0:00:18
#    -- ------------------------------------- 24.9/375.9 MB 19.5 MB/s eta 0:00:19
#    --- ------------------------------------ 28.3/375.9 MB 18.9 MB/s eta 0:00:19
#    --- ------------------------------------ 32.0/375.9 MB 18.6 MB/s eta 0:00:19
#    --- ------------------------------------ 35.9/375.9 MB 18.5 MB/s eta 0:00:19
#    ---- ----------------------------------- 39.6/375.9 MB 18.5 MB/s eta 0:00:19
#    ---- ----------------------------------- 44.3/375.9 MB 18.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 48.5/375.9 MB 18.9 MB/s eta 0:00:18
#    ----- ---------------------------------- 51.9/375.9 MB 18.7 MB/s eta 0:00:18
#    ----- ---------------------------------- 54.0/375.9 MB 18.8 MB/s eta 0:00:18
#    ------ --------------------------------- 60.6/375.9 MB 19.0 MB/s eta 0:00:17
#    ------ --------------------------------- 64.0/375.9 MB 18.8 MB/s eta 0:00:17
#    ------- -------------------------------- 67.1/375.9 MB 18.6 MB/s eta 0:00:17
#    ------- -------------------------------- 70.0/375.9 MB 18.4 MB/s eta 0:00:17
#    ------- -------------------------------- 71.8/375.9 MB 17.8 MB/s eta 0:00:18
#    -------- ------------------------------- 75.5/375.9 MB 17.8 MB/s eta 0:00:17
#    -------- ------------------------------- 79.2/375.9 MB 17.8 MB/s eta 0:00:17
#    ------------------------- ------------- 244.1/375.9 MB 18.4 MB/s eta 0:00:08
#    ------------------------- ------------- 248.0/375.9 MB 18.4 MB/s eta 0:00:07
#    -------------------------- ------------ 252.7/375.9 MB 18.4 MB/s eta 0:00:07
#    -------------------------- ------------ 257.2/375.9 MB 18.5 MB/s eta 0:00:07
#    --------------------------- ----------- 261.6/375.9 MB 18.5 MB/s eta 0:00:07
#    --------------------------- ----------- 266.3/375.9 MB 18.5 MB/s eta 0:00:06
#    ---------------------------- ---------- 270.5/375.9 MB 18.5 MB/s eta 0:00:06
#    ---------------------------- ---------- 272.6/375.9 MB 18.4 MB/s eta 0:00:06
#    ---------------------------- ---------- 275.0/375.9 MB 18.3 MB/s eta 0:00:06
#    ---------------------------- ---------- 277.9/375.9 MB 18.2 MB/s eta 0:00:06
#    ----------------------------- --------- 280.8/375.9 MB 18.1 MB/s eta 0:00:06
#    ----------------------------- --------- 283.6/375.9 MB 18.0 MB/s eta 0:00:06
#    ----------------------------- --------- 286.5/375.9 MB 18.0 MB/s eta 0:00:05
#    ------------------------------ -------- 289.7/375.9 MB 18.0 MB/s eta 0:00:05
#    ------------------------------ -------- 292.8/375.9 MB 17.9 MB/s eta 0:00:05
#    ------------------------------ -------- 296.0/375.9 MB 17.9 MB/s eta 0:00:05
#    ------------------------------- ------- 298.8/375.9 MB 17.8 MB/s eta 0:00:05
#    ------------------------------- ------- 302.3/375.9 MB 17.8 MB/s eta 0:00:05
#    ------------------------------- ------- 306.2/375.9 MB 17.7 MB/s eta 0:00:04
#    -------------------------------- ------ 309.9/375.9 MB 17.7 MB/s eta 0:00:04
#    -------------------------------- ------ 314.3/375.9 MB 17.8 MB/s eta 0:00:04
#    --------------------------------- ----- 319.6/375.9 MB 17.8 MB/s eta 0:00:04
#    --------------------------------- ----- 325.6/375.9 MB 18.0 MB/s eta 0:00:03
#    ---------------------------------- ---- 330.8/375.9 MB 18.1 MB/s eta 0:00:03
#    ---------------------------------- ---- 334.8/375.9 MB 18.4 MB/s eta 0:00:03
#    ----------------------------------- --- 339.7/375.9 MB 18.4 MB/s eta 0:00:02
#    ----------------------------------- --- 346.0/375.9 MB 18.6 MB/s eta 0:00:02
#    ------------------------------------ -- 348.9/375.9 MB 18.5 MB/s eta 0:00:02
#    ------------------------------------ -- 353.9/375.9 MB 18.5 MB/s eta 0:00:02
#    ------------------------------------- - 357.0/375.9 MB 18.4 MB/s eta 0:00:02
#    ------------------------------------- - 361.8/375.9 MB 18.4 MB/s eta 0:00:01
#    --------------------------------------  367.3/375.9 MB 18.5 MB/s eta 0:00:01
#    --------------------------------------  370.9/375.9 MB 18.5 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    --------------------------------------  375.7/375.9 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 375.9/375.9 MB 16.0 MB/s  0:00:22
# Installing collected packages: numpy, tensorflow, pmdarima
#
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ---------------------------------------- 0/3 [numpy]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    ------------- -------------------------- 1/3 [tensorflow]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    -------------------------- ------------- 2/3 [pmdarima]
#    ---------------------------------------- 3/3 [pmdarima]
#
# Successfully installed numpy-1.26.4 pmdarima-2.0.4 tensorflow-2.19.0
